# %%
from convertuploaddocument import *

cud = convertuploaddocument(searchpath = '\\\\data.wexac.weizmann.ac.il\\rivlinlab-arc\\raw\\user=AH\\date=190825\\', 
                            WexacH5Path = '\\\\data.wexac.weizmann.ac.il\\rivlinlab-arc\\h5s\\',
                            startfresh=True, cloudflag = "None", localcopyflag = False)

# %%
cud.scanforexperiments()

# %%
cud.parsefields(getvalchar=['=', '>'], nextfieldchar=[',', '_'])

# %%
cud.wexac_copy()

# %%
cud.field.to_excel(os.path.join(cud.WexacH5Path, 'experiments.xlsx'), index=False)

# %%
cud.field
# Out:
#                                          fullpathmsrd      exclude  \
# 0   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 1   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 2   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 3   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 4   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 5   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 6   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 7   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 8   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 9   \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 10  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 11  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 12  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 13  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 14  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 15  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 16  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
# 17  \\data.wexac.weizmann.ac.il\rivlinlab-arc\raw\...  unspecified
#
#                                             folder      coating     cleaning  \
# 0   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 1   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 2   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 3   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 4   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 5   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 6   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 7   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 8   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 9   \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 10  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 11  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 12  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 13  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 14  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 15  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 16  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
# 17  \\data.wexac.weizmann.ac.il\rivlinlab-arc\h5s\  unspecified  unspecified
#
#                                 MEAfiles        recFormat  \
# 0   a0a5f2f1533d1d9aac8b3c95c36181e2.bin  binaryRecording
# 1    a0a5f2f1533d1d9aac8b3c95c36181e2.h5    MCH5Recording
# 2   356d6fc2221630be721c4e8bedef0d46.bin  binaryRecording
# 3    356d6fc2221630be721c4e8bedef0d46.h5    MCH5Recording
# 4   5166139b51819e4a1837b90809405901.bin  binaryRecording
# 5    5166139b51819e4a1837b90809405901.h5    MCH5Recording
# 6   cce19c177233ae9fdb66f3cd1e335e5e.bin  binaryRecording
# 7    cce19c177233ae9fdb66f3cd1e335e5e.h5    MCH5Recording
# 8   d3ec8f0569608740a2217a363394055f.bin  binaryRecording
# 9    d3ec8f0569608740a2217a363394055f.h5    MCH5Recording
# 10  56e0f754e2a777f68bd602f56ff2e75b.bin  binaryRecording
# 11   56e0f754e2a777f68bd602f56ff2e75b.h5    MCH5Recording
# 12  38a709e578bcac26e95014db94d7a8c3.bin  binaryRecording
# 13   38a709e578bcac26e95014db94d7a8c3.h5    MCH5Recording
# 14  816965f639d90236d636ff5418294b0f.bin  binaryRecording
# 15   816965f639d90236d636ff5418294b0f.h5    MCH5Recording
# 16  f0e4f44db7fe0f1e1691e8ae06972a0a.bin  binaryRecording
# 17   f0e4f44db7fe0f1e1691e8ae06972a0a.h5    MCH5Recording
#
#                                 recNames     comments  \
# 0   a0a5f2f1533d1d9aac8b3c95c36181e2.bin  unspecified
# 1    a0a5f2f1533d1d9aac8b3c95c36181e2.h5  unspecified
# 2   356d6fc2221630be721c4e8bedef0d46.bin  unspecified
# 3    356d6fc2221630be721c4e8bedef0d46.h5  unspecified
# 4   5166139b51819e4a1837b90809405901.bin  unspecified
# 5    5166139b51819e4a1837b90809405901.h5  unspecified
# 6   cce19c177233ae9fdb66f3cd1e335e5e.bin  unspecified
# 7    cce19c177233ae9fdb66f3cd1e335e5e.h5  unspecified
# 8   d3ec8f0569608740a2217a363394055f.bin  unspecified
# 9    d3ec8f0569608740a2217a363394055f.h5  unspecified
# 10  56e0f754e2a777f68bd602f56ff2e75b.bin  unspecified
# 11   56e0f754e2a777f68bd602f56ff2e75b.h5  unspecified
# 12  38a709e578bcac26e95014db94d7a8c3.bin  unspecified
# 13   38a709e578bcac26e95014db94d7a8c3.h5  unspecified
# 14  816965f639d90236d636ff5418294b0f.bin  unspecified
# 15   816965f639d90236d636ff5418294b0f.h5  unspecified
# 16  f0e4f44db7fe0f1e1691e8ae06972a0a.bin  unspecified
# 17   f0e4f44db7fe0f1e1691e8ae06972a0a.h5  unspecified
#
#                                        OrigFileFolder  \
# 0   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 1   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 2   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 3   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 4   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 5   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 6   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 7   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 8   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 9   \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 10  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 11  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 12  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 13  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 14  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 15  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 16  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
# 17  \data.wexac.weizmann.ac.il\rivlinlab-arc\raw\u...
#
#                                          OrigFileName user    date  \
# 0   2019-08-25T16-37-34type=SystemCalibration,MEA=...   AH  190825
# 1   2019-08-25T16-37-34type=SystemCalibration,MEA=...   AH  190825
# 2   2019-08-25T16-41-29type=SystemCalibration,MEA=...   AH  190825
# 3   2019-08-25T16-41-29type=SystemCalibration,MEA=...   AH  190825
# 4   2019-08-25T16-53-07type=SystemCalibration,MEA=...   AH  190825
# 5   2019-08-25T16-53-07type=SystemCalibration,MEA=...   AH  190825
# 6   2019-08-25T17-07-03type=SystemCalibration,MEA=...   AH  190825
# 7   2019-08-25T17-07-03type=SystemCalibration,MEA=...   AH  190825
# 8   2019-08-25T17-08-52type=SystemCalibration,MEA=...   AH  190825
# 9   2019-08-25T17-08-52type=SystemCalibration,MEA=...   AH  190825
# 10  2019-08-25T17-15-00type=SystemCalibration,MEA=...   AH  190825
# 11  2019-08-25T17-15-00type=SystemCalibration,MEA=...   AH  190825
# 12  2019-08-25T17-16-20type=SystemCalibration,MEA=...   AH  190825
# 13  2019-08-25T17-16-20type=SystemCalibration,MEA=...   AH  190825
# 14  2019-08-25T17-23-33type=SystemCalibration,MEA=...   AH  190825
# 15  2019-08-25T17-23-33type=SystemCalibration,MEA=...   AH  190825
# 16  2019-08-25T17-37-00type=SystemCalibration,MEA=...   AH  190825
# 17  2019-08-25T17-37-00type=SystemCalibration,MEA=...   AH  190825
#
#                  type    MEA     mouse  tissue    eye run         stims
# 0   SystemCalibration  18385  negGcamp  dorsal  right   1         spots
# 1   SystemCalibration  18385  negGcamp  dorsal  right   1         spots
# 2   SystemCalibration  18385  negGcamp  dorsal  right   1      gratings
# 3   SystemCalibration  18385  negGcamp  dorsal  right   1      gratings
# 4   SystemCalibration  18385  negGcamp  dorsal  right   1          bars
# 5   SystemCalibration  18385  negGcamp  dorsal  right   1          bars
# 6   SystemCalibration  18385  negGcamp  dorsal  right   1        wnoise
# 7   SystemCalibration  18385  negGcamp  dorsal  right   1        wnoise
# 8   SystemCalibration  18385  negGcamp  dorsal  right   1     dark-hist
# 9   SystemCalibration  18385  negGcamp  dorsal  right   1     dark-hist
# 10  SystemCalibration  18385  negGcamp  dorsal  right   2         spots
# 11  SystemCalibration  18385  negGcamp  dorsal  right   2         spots
# 12  SystemCalibration  18385  negGcamp  dorsal  right   2      gratings
# 13  SystemCalibration  18385  negGcamp  dorsal  right   2      gratings
# 14  SystemCalibration  18385  negGcamp  dorsal  right   2          bars
# 15  SystemCalibration  18385  negGcamp  dorsal  right   2          bars
# 16  SystemCalibration  18385  negGcamp  dorsal  right   2  dark-washout
# 17  SystemCalibration  18385  negGcamp  dorsal  right   2  dark-washout
